# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 62.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 89.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.1 MB/s eta 0:00:00
# ...

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2-large', pad_token_id=tokenizer.eos_token_id)

# %%
data = ''
while True:
  sentence = input()
  data += ' ' + sentence
  print(data)
  numeric_ids = tokenizer.encode(data, return_tensors='pt')
  result = model.generate(numeric_ids, max_length = len(numeric_ids[0])+2, num_beams=2, no_repeat_ngram_size=2, early_stopping=True)
  generated_text = tokenizer.decode(result[0][-2:], skip_special_tokens=True)
  print(generated_text)
# Out:
# I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was
#  Monaco.
# Monaco
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco
# .
#
# and
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco and
#  it was
# Paris.
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco and Paris.
#
#
#
# I visited
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco and Paris. I visited
#  all of
# various
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco and Paris. I visited various
#  places in
# places in
#  I visited Monaco, Paris and Barcelona in my recent trip to Europe. May favorite city was Monaco and Paris. I visited various places in
# ...
